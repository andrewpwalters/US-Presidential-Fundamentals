# %%
import datetime

import arviz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pytensor.tensor as aet #pt
from scipy.special import expit as logistic
import arviz as az

from itertools import product
import datetime as dt

def inv_logit(p):
    return np.exp(p) / (1 + np.exp(p))
def logit(p):
    return np.log(p)-np.log(1-p)

# %%
president_polls_url = 'https://projects.fivethirtyeight.com/polls/data/president_polls.csv'
df = pd.read_csv(president_polls_url)

df.loc[(df['party'].isin(['REP', 'DEM']) == False) & (df['answer'] != 'Kennedy'), 'party'] = 'OTH'
df = df[df['party'] != 'OTH'

# %%
df.query("poll_id == 87324")
# Out:
#      poll_id  pollster_id        pollster sponsor_ids           sponsors  \
# 327    87324         1878  SoCal Research        2152  On Point Politics
# 328    87324         1878  SoCal Research        2152  On Point Politics
# 329    87324         1878  SoCal Research        2152  On Point Politics
# 330    87324         1878  SoCal Research        2152  On Point Politics
# 334    87324         1878  SoCal Research        2152  On Point Politics
#
#        display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 327  SoCal Research                 851       SoCal Research            NaN
# 328  SoCal Research                 851       SoCal Research            NaN
# 329  SoCal Research                 851       SoCal Research            NaN
# 330  SoCal Research                 851       SoCal Research            NaN
# 334  SoCal Research                 851       SoCal Research            NaN
#
#      pollscore  ... election_date    stage nationwide_batch  \
# 327        NaN  ...       11/5/24  general            False
# 328        NaN  ...       11/5/24  general            False
# 329        NaN  ...       11/5/24  general            False
# 330        NaN  ...       11/5/24  general            False
# 334        NaN  ...       11/5/24  general            False
#
#     ranked_choice_reallocated ranked_choice_round  party   answer  \
# 327                     False                 NaN    DEM    Biden
# 328                     False                 NaN    REP    Trump
# 329                     False                 NaN    DEM    Biden
# 330                     False                 NaN    REP    Trump
# 334                     False                 NaN    IND  Kennedy
#
#     candidate_id     candidate_name   pct
# 327        19368          Joe Biden  41.0
# 328        16651       Donald Trump  44.0
# 329        19368          Joe Biden  35.0
# 330        16651       Donald Trump  41.0
# 334        31042  Robert F. Kennedy   8.0
#
# [5 rows x 48 columns]

# %%
df.query("poll_id == 87324")
# Out:
#      poll_id  pollster_id        pollster sponsor_ids           sponsors  \
# 327    87324         1878  SoCal Research        2152  On Point Politics
# 328    87324         1878  SoCal Research        2152  On Point Politics
# 329    87324         1878  SoCal Research        2152  On Point Politics
# 330    87324         1878  SoCal Research        2152  On Point Politics
# 334    87324         1878  SoCal Research        2152  On Point Politics
#
#        display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 327  SoCal Research                 851       SoCal Research            NaN
# 328  SoCal Research                 851       SoCal Research            NaN
# 329  SoCal Research                 851       SoCal Research            NaN
# 330  SoCal Research                 851       SoCal Research            NaN
# 334  SoCal Research                 851       SoCal Research            NaN
#
#      pollscore  ... election_date    stage nationwide_batch  \
# 327        NaN  ...       11/5/24  general            False
# 328        NaN  ...       11/5/24  general            False
# 329        NaN  ...       11/5/24  general            False
# 330        NaN  ...       11/5/24  general            False
# 334        NaN  ...       11/5/24  general            False
#
#     ranked_choice_reallocated ranked_choice_round  party   answer  \
# 327                     False                 NaN    DEM    Biden
# 328                     False                 NaN    REP    Trump
# 329                     False                 NaN    DEM    Biden
# 330                     False                 NaN    REP    Trump
# 334                     False                 NaN    IND  Kennedy
#
#     candidate_id     candidate_name   pct
# 327        19368          Joe Biden  41.0
# 328        16651       Donald Trump  44.0
# 329        19368          Joe Biden  35.0
# 330        16651       Donald Trump  41.0
# 334        31042  Robert F. Kennedy   8.0
#
# [5 rows x 48 columns]

# %%
df = pd.read_csv("../Data/raw/president_polls.csv")
