# %%
import datetime

import arviz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pytensor.tensor as aet #pt
from scipy.special import expit as logistic
import arviz as az

from itertools import product
import datetime as dt

def inv_logit(p):
    return np.exp(p) / (1 + np.exp(p))
def logit(p):
    return np.log(p)-np.log(1-p)

# %%
president_polls_url = 'https://projects.fivethirtyeight.com/polls/data/president_polls.csv'
df = pd.read_csv(president_polls_url)

df.loc[(df['party'].isin(['REP', 'DEM']) == False) & (df['answer'] != 'Kennedy'), 'party'] = 'OTH'
df = df[df['party'] != 'OTH']

# %%
df.query("poll_id == 87324")
# Out:
#      poll_id  pollster_id        pollster sponsor_ids           sponsors  \
# 273    87324         1878  SoCal Research        2152  On Point Politics
# 274    87324         1878  SoCal Research        2152  On Point Politics
# 275    87324         1878  SoCal Research        2152  On Point Politics
# 276    87324         1878  SoCal Research        2152  On Point Politics
# 277    87324         1878  SoCal Research        2152  On Point Politics
# 278    87324         1878  SoCal Research        2152  On Point Politics
# 279    87324         1878  SoCal Research        2152  On Point Politics
# 280    87324         1878  SoCal Research        2152  On Point Politics
#
#        display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 273  SoCal Research                 851       SoCal Research            NaN
# 274  SoCal Research                 851       SoCal Research            NaN
# 275  SoCal Research                 851       SoCal Research            NaN
# 276  SoCal Research                 851       SoCal Research            NaN
# 277  SoCal Research                 851       SoCal Research            NaN
# 278  SoCal Research                 851       SoCal Research            NaN
# 279  SoCal Research                 851       SoCal Research            NaN
# 280  SoCal Research                 851       SoCal Research            NaN
#
#      pollscore  ... election_date    stage nationwide_batch  \
# 273        NaN  ...       11/5/24  general            False
# 274        NaN  ...       11/5/24  general            False
# 275        NaN  ...       11/5/24  general            False
# 276        NaN  ...       11/5/24  general            False
# 277        NaN  ...       11/5/24  general            False
# 278        NaN  ...       11/5/24  general            False
# 279        NaN  ...       11/5/24  general            False
# 280        NaN  ...       11/5/24  general            False
#
#     ranked_choice_reallocated ranked_choice_round  party   answer  \
# 273                     False                 NaN    DEM    Biden
# 274                     False                 NaN    REP    Trump
# 275                     False                 NaN    DEM    Biden
# 276                     False                 NaN    REP    Trump
# 277                     False                 NaN    OTH   Oliver
# 278                     False                 NaN    OTH     West
# 279                     False                 NaN    OTH    Stein
# 280                     False                 NaN    IND  Kennedy
#
#     candidate_id     candidate_name   pct
# 273        19368          Joe Biden  41.0
# 274        16651       Donald Trump  44.0
# 275        19368          Joe Biden  35.0
# 276        16651       Donald Trump  41.0
# 277        31790       Chase Oliver   1.0
# 278        31097        Cornel West   2.0
# 279        31116         Jill Stein   2.0
# 280        31042  Robert F. Kennedy   8.0
#
# [8 rows x 48 columns]

# %%
df.query("poll_id == 87324")
# Out:
#      poll_id  pollster_id        pollster sponsor_ids           sponsors  \
# 273    87324         1878  SoCal Research        2152  On Point Politics
# 274    87324         1878  SoCal Research        2152  On Point Politics
# 275    87324         1878  SoCal Research        2152  On Point Politics
# 276    87324         1878  SoCal Research        2152  On Point Politics
# 280    87324         1878  SoCal Research        2152  On Point Politics
#
#        display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 273  SoCal Research                 851       SoCal Research            NaN
# 274  SoCal Research                 851       SoCal Research            NaN
# 275  SoCal Research                 851       SoCal Research            NaN
# 276  SoCal Research                 851       SoCal Research            NaN
# 280  SoCal Research                 851       SoCal Research            NaN
#
#      pollscore  ... election_date    stage nationwide_batch  \
# 273        NaN  ...       11/5/24  general            False
# 274        NaN  ...       11/5/24  general            False
# 275        NaN  ...       11/5/24  general            False
# 276        NaN  ...       11/5/24  general            False
# 280        NaN  ...       11/5/24  general            False
#
#     ranked_choice_reallocated ranked_choice_round  party   answer  \
# 273                     False                 NaN    DEM    Biden
# 274                     False                 NaN    REP    Trump
# 275                     False                 NaN    DEM    Biden
# 276                     False                 NaN    REP    Trump
# 280                     False                 NaN    IND  Kennedy
#
#     candidate_id     candidate_name   pct
# 273        19368          Joe Biden  41.0
# 274        16651       Donald Trump  44.0
# 275        19368          Joe Biden  35.0
# 276        16651       Donald Trump  41.0
# 280        31042  Robert F. Kennedy   8.0
#
# [5 rows x 48 columns]

# %%
df = pd.read_csv("../Data/raw/president_polls.csv")
